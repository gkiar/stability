# %%
from nilearn.plotting import plot_anat, plot_glass_brain, plot_roi
from nilearn.image import reorder_img, resample_img, resample_to_img
from nilearn.datasets import load_mni152_template

import nibabel as nib
import numpy as np

# %matplotlib inline

# %%
f1 = './transform_Warped.nii.gz'
i1 = nib.load(f1)
d1 = i1.get_data()

# %%
def addNoise(da1):
    tmp = 200*np.random.rand(*da1.shape)
    return da1 + tmp

d2 = addNoise(d1)
i2 = nib.Nifti1Image(d2, i1.affine, i1.header)

# %%
template = load_mni152_template()
template

# %%
import checkerboard

# %%
i4 = checkerboard.checkerNiftii(i1, i2)

# %%
from data2sprite import data2sprite
import png

# %%
d5 = data2sprite(i4.get_data())
print(d5.min(), d5.max(), np.sum(entropy(d5)))
d5 *= (32767.0/d5.max())
print(d5.min(), d5.max(), np.sum(entropy(d5)))
d5 = d5.astype('int16')
print(d5.min(), d5.max(), np.sum(entropy(d5)))
my = png.from_array(d5, 'L').save('tmp.png')
# Out:
# 0.0 623.2482937127771 6576.270384779662
# 0.0 32767.0 6576.270384779663
# 0 32767 6576.232755760353

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-3a4cfd0250a2> in <module>
# ----> 1 tuple(r for r in my.rows).max()
#
# AttributeError: 'tuple' object has no attribute 'max'

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import entropy

# %%
d4 = i4.get_data()
d4 *= 255.0/d4.max()
i6 = nib.Nifti1Image(d4, i4.affine, i4.header)
plot_anat(i6)

# %%
plot_anat(i4)

# %%
print(template.affine)
print(i1.affine)
resample_to_img()
# Out:
# [[  -2.    0.    0.   90.]
#  [   0.    2.    0. -126.]
#  [   0.    0.    2.  -72.]
#  [   0.    0.    0.    1.]]
# [[  -2.   -0.    0.   90.]
#  [  -0.    2.   -0. -126.]
#  [   0.    0.    2.  -72.]
#  [   0.    0.    0.    1.]]

# %%
plot_anat(i3)
